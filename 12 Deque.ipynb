# %%
#1 WHAT IS DEQUE

# Deque is a data structure that can be used to store a collection of elements. It is a linear data structure, which means that the elements are stored in a sequence.
# Enqueue is an operation that adds an element to the end of a deque.
# Dequeue is an operation that removes an element from the beginning of a deque.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2 APPLICATION OF DEQUE

# A deque can be used as both stack and queue
# Buffer of limited size..maint history of action..add to rear..start removing from front once buffer becomes full..
# A steal process scheduling alogrithm - if two processors are available..one is busy and one is free..p1 will pick from front (deletion) and add in rear..p2 will pick from rear of p1..and delete it...therefore it will required deletion at both end..

# Priority queue with type types of priorities..keep adding priority 1 item at front and p2 item at rear..picking/deletion from front..in this way all priority 1 items will be picked and finished first before priority 2

# Maximum/minimum of all subarryas

# %% [markdown]
# ![image.png](attachment:image.png)
