# %%
# 1. PROBLEMS with arrays

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Round Robin sceduling

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Another problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Problem 3 merge sort..if we have list..during merging we need ausxilay space...if we use linked list we wount need to use
